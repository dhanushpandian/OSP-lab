# %%
import pandas as pd

# %%
d=pd.read_csv("air_pollution_data.csv")

# %%
d=d.head(20)
print(d)
# Out:
#          city        date  aqi       co     no     no2      o3     so2  \
# 0   Ahmedabad  30-11-2020    5   520.71   2.38   16.28  130.18   47.68
# 1   Ahmedabad  01-12-2020    5  1682.28   7.71   54.84    0.73   21.70
# 2   Ahmedabad  02-12-2020    5  1815.80  16.54   49.35    0.17   23.84
# 3   Ahmedabad  03-12-2020    5  2296.45  41.57   40.10    0.00   35.76
# 4   Ahmedabad  04-12-2020    5  2189.64  23.92   58.95    0.02   28.13
# 5   Ahmedabad  05-12-2020    5  3845.22  57.22  137.09    0.00  110.63
# 6   Ahmedabad  06-12-2020    5  2883.91  27.94   98.71    0.02   84.88
# 7   Ahmedabad  07-12-2020    5  1628.88  19.89   40.10    0.02   21.22
# 8   Ahmedabad  08-12-2020    5  1735.69   9.28   59.63    0.59   25.99
# 9   Ahmedabad  09-12-2020    5  2857.21  34.87   69.92    0.00   46.25
# 10  Ahmedabad  10-12-2020    5  1762.39   6.48   67.17    1.54   28.61
# 11  Ahmedabad  11-12-2020    5   540.73   0.00   16.79   91.55   21.46
# ...

# %%
d.shape
# Out:
# (20, 11)

# %%
del d['date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
d
# Out:
#          city  aqi       co     no     no2      o3     so2   pm2_5    pm10  \
# 0   Ahmedabad    5   520.71   2.38   16.28  130.18   47.68   65.96   72.13
# 1   Ahmedabad    5  1682.28   7.71   54.84    0.73   21.70  120.95  154.53
# 2   Ahmedabad    5  1815.80  16.54   49.35    0.17   23.84  133.47  172.63
# 3   Ahmedabad    5  2296.45  41.57   40.10    0.00   35.76  150.37  202.15
# 4   Ahmedabad    5  2189.64  23.92   58.95    0.02   28.13  160.79  205.80
# 5   Ahmedabad    5  3845.22  57.22  137.09    0.00  110.63  249.51  322.46
# 6   Ahmedabad    5  2883.91  27.94   98.71    0.02   84.88  232.03  281.96
# 7   Ahmedabad    5  1628.88  19.89   40.10    0.02   21.22  106.27  143.12
# 8   Ahmedabad    5  1735.69   9.28   59.63    0.59   25.99  122.37  163.42
# 9   Ahmedabad    5  2857.21  34.87   69.92    0.00   46.25  213.63  276.18
# 10  Ahmedabad    5  1762.39   6.48   67.17    1.54   28.61  145.72  184.11
# ...

# %%
d.loc[d["city"]!='Ahmedabad']
# Out:
# Empty DataFrame
# Columns: [city, aqi, co, no, no2, o3, so2, pm2_5, pm10, nh3]
# Index: []

# %%
d[2:5]
# Out:
#         city  aqi       co     no    no2    o3    so2   pm2_5    pm10    nh3
# 2  Ahmedabad    5  1815.80  16.54  49.35  0.17  23.84  133.47  172.63  28.12
# 3  Ahmedabad    5  2296.45  41.57  40.10  0.00  35.76  150.37  202.15  36.48
# 4  Ahmedabad    5  2189.64  23.92  58.95  0.02  28.13  160.79  205.80  40.53

# %%
d['name']=['a','']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\91638\OneDrive\Desktop\git files\OSP\load.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91638/OneDrive/Desktop/git%20files/OSP/load.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> d['name']=['a']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
# ...

# %%
d.to_csv('new.csv')

# %%
f=open("file.text","w")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='file.text' mode='w' encoding='cp1252'>

# %%
f.write("first line \n")
f
f.write("second line \n")
f.close()

# %%
x="{1:"one",2:"two",3:"three"}"
x
# Out:
#   Cell In[27], line 1
#     x="{1:"one",2:"two",3:"three"}"
#            ^
# SyntaxError: invalid syntax

# %%
import json

# %%
y=json.loads(x)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\91638\OneDrive\Desktop\git files\OSP\python.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91638/OneDrive/Desktop/git%20files/OSP/python.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> y=json.loads(x)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([0,6])
y=np.array([0,250])

print(x,"\n",y)
# Out:
# [0 6]
#  [  0 250]

# %%
plt.plot(x,y,marker="o")

# %%
p=[1,2,3,4]
plt.pie(p,labels=['dash','sara','jay','arun'])
# Out:
# ([<matplotlib.patches.Wedge at 0x21ad57073d0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'dash'),
#   Text(0.33991867422268784, 1.0461621742897658, 'sara'),
#   Text(-1.0461621902025062, 0.3399186252483017, 'jay'),
#   Text(0.3399188211458418, -1.0461621265515308, 'arun')])

# %%
plt.hist(p)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
import plotly.express as px

# %%
fig=px.scatter(p)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\91638\OneDrive\Desktop\git files\OSP\python.ipynb Cell 23 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/91638/OneDrive/Desktop/git%20files/OSP/python.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> fig=px.scatter(p)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91638/OneDrive/Desktop/git%20files/OSP/python.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\plotly\basedatatypes.py:3412, in BaseFigure.show(self, *args, **kwargs)
#    3379 """
#    3380 Show a figure using either the default renderer(s) or the renderer(s)
#    3381 specified by the renderer argument
#    (...)
#    3408 None
#    3409 """
#    3410 import plotly.io as pio
# -> 3412 return pio.show(self, *args, **kwargs)
#
# ...

# %%
import cv2

# %%
i=cv2.imread("Screenshot 2023-04-06 121640.png")
i
# Out:
# array([[[42, 25, 19],
#         [42, 25, 19],
#         [42, 25, 19],
#         ...,
#         [31, 20, 10],
#         [31, 21, 10],
#         [31, 21, 10]],
#
#        [[43, 25, 18],
#         [44, 25, 19],
#         [44, 25, 19],
#         ...,
#         [31, 21, 10],
#         [32, 21, 10],
#         [30, 21, 10]],
#
#        [[43, 25, 17],
#         [44, 25, 18],
#         [44, 25, 18],
#         ...,
#         [32, 21, 10],
#         [32, 21, 10],
#         [31, 21, 10]],
#
#        ...,
#
#        [[45, 31, 24],
#         [43, 30, 25],
#         [40, 29, 24],
#         ...,
#         [37, 27, 18],
#         [37, 27, 18],
#         [37, 27, 18]],
#
#        [[42, 29, 24],
#         [40, 28, 23],
#         [38, 27, 22],
#         ...,
#         [37, 28, 18],
#         [37, 27, 18],
#         [37, 27, 18]],
#
#        [[41, 28, 24],
#         [39, 27, 22],
#         [36, 26, 20],
#         ...,
#         [37, 28, 18],
#         [37, 28, 18],
#         [37, 27, 18]]], dtype=uint8)

# %%
h,w,c=i.shape
print(h,w,c)
# Out:
# 1080 1920 3

# %%
cv2.imshow("valo",i)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
# ...

# %%
cv2.imwrite("valo.jpeg",i)
# Out:
# True

# %%
b,g,r=cv2.split(i)
print(b,g,r)
# Out:
# [[42 42 42 ... 31 31 31]
#  [43 44 44 ... 31 32 30]
#  [43 44 44 ... 32 32 31]
#  ...
#  [45 43 40 ... 37 37 37]
#  [42 40 38 ... 37 37 37]
#  [41 39 36 ... 37 37 37]] [[25 25 25 ... 20 21 21]
#  [25 25 25 ... 21 21 21]
#  [25 25 25 ... 21 21 21]
#  ...
#  [31 30 29 ... 27 27 27]
#  [29 28 27 ... 28 27 27]
#  [28 27 26 ... 28 28 27]] [[19 19 19 ... 10 10 10]
#  [18 19 19 ... 10 10 10]
#  [17 18 18 ... 10 10 10]
#  ...
#  [24 25 24 ... 18 18 18]
#  [24 23 22 ... 18 18 18]
#  [24 22 20 ... 18 18 18]]

# %%
i2=cv2.imread("Screenshot 2023-06-01 215459.png")
cv2.imwrite("valo2.jpeg",i2)
# Out:
# True

# %%
add=i-i2
plt.imshow(add)

# %%
plt.imshow(i-i2)

# %%
plt.imshow( i*i2)

# %%
plt.imshow(i/i2)
# Out:
# C:\Users\91638\AppData\Local\Temp\ipykernel_22904\1000168956.py:1: RuntimeWarning: divide by zero encountered in divide
#   plt.imshow(i/i2)
# C:\Users\91638\AppData\Local\Temp\ipykernel_22904\1000168956.py:1: RuntimeWarning: invalid value encountered in divide
#   plt.imshow(i/i2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
i3=cv2.putText(i,"valorant",(50,50),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),5,cv2.LINE_AA)
plt.imshow(i3)
